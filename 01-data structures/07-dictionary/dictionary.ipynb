# %% [markdown]
# ### Exercise: Dictionary of Student Grades
#
# Create a dictionary containing grades for four students: `sara`, `alex`, `ferial`, and `farnia`.
#
# For each student, store their grades for the following subjects:
# - `physics`
# - `math`
# - `history`
# - `art`
#
# Then, print the **math grade of `ferial`**.

# %%
mark = {
    "sara":{
        "physics": 16,
        "math": 20,
        "history": 12,
        "art": 18.5
    },

    "alex":{
        "physics": 18.75,
        "math": 10,
        "history": 20,
        "art": 15
    },

    "ferial":{
        "physics": 13,
        "math": 17,
        "history": 19,
        "art": 5
    },

    "farnia":{
        "physics": 17,
        "math":19.5,
        "history":20,
        "art":20
    }
} 

mark["ferial"]["math"]
# Out:
# 17
