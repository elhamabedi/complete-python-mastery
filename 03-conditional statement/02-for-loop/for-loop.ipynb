# %% [markdown]
# **Exercise – Product Dictionary**
#
# Create a dictionary with product names as keys (e.g., `"rice"`, `"oil"`, `"pasta"`).
# The value for each key is a list of two items: `[unit price, quantity]`.
#
# Then, print the name of each product and its **unit price**.

# %%
products = {
    "rice" : (1000, 12000),
    "oil" : (100, 800),
    "pasta" : (120, 2000 )
}

for product in products:
    print(product, products[product][0])
# Out:
# rice 1000
# oil 100
# pasta 120
