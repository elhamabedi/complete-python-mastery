# %%
list = [3, 56, 89, 88, 100, 0]

new_list = [i*2 for i in list]
print(new_list)
# Out:
# [6, 112, 178, 176, 200, 0]

# %%
list_1 = [67, 89, 0, 100, 2, 45, 789]

new_list_1 = ["even" if i%2==0  else "odd" for i in list_1]
print(new_list_1)
# Out:
# ['odd', 'odd', 'even', 'even', 'even', 'odd', 'odd']
